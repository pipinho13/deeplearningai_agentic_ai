# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    Write a complete, well-structured essay on the following topic:

    "{topic}"

    The essay should include:
    - A clear and engaging introduction
    - At least 2–3 body paragraphs with supporting arguments and examples
    - A strong conclusion that summarizes the main points

    Use clear, formal language and make the essay coherent and logically organized.
    Aim for approximately 400–600 words.
    """ 

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an expert writing instructor. Review the following essay draft and provide constructive, critical feedback.

    Essay:
    "{draft}"

    In your response:
    - Evaluate the overall structure (introduction, body, conclusion)
    - Comment on clarity and coherence of ideas
    - Assess the strength and support of arguments
    - Provide feedback on writing style, tone, and grammar
    - Point out specific areas for improvement and explain why

    Do NOT rewrite the essay. Focus only on analysis and suggestions.
    Write your feedback as a well-organized paragraph.
    """ 

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an expert writer. Revise the following essay draft based on the feedback provided.

    Original Draft:
    "{original_draft}"

    Feedback/Reflection:
    "{reflection}"

    Revise the essay to:
    - Address all points mentioned in the feedback
    - Improve clarity, coherence, and flow
    - Strengthen arguments and provide better examples if needed
    - Maintain a formal, clear, and well-structured style

    Return ONLY the revised essay. Do not include any commentary or notes.
    """ 

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# **Should Social Media Platforms Be Regulated by the Government?**
#
# In the digital era, social media platforms represent a transformative force in how individuals communicate, express ideas, and consume information. These platforms have become indispensable, influencing political discourse, societal norms, and even individual well-being. However, the question of whether these platforms should be regulated by the government is a contentious issue, stoking debates about freedom of expression, misinformation, and privacy. While social media provides a space for free expression and connection, government regulation may be necessary to mitigate harmful effects such as the spread of misinformation, violation of privacy, and cyberbullying.
#
# One primary argument for government regulation of social media platforms is the need to combat the rampant spread of misinformation. The past decade has seen numerous instances of false information spreading virally, often with significant real-world consequences. For example, during political elections, misleading or outright false information can influence public opinion and voter behavior. The dissemination of inaccurate health information, particularly evident during the COVID-19 pandemic, poses risks to public health and safety. Government intervention could help ensure that these platforms implement more stringent measures for fact-checking and moderating content, thus preserving the integrity of information shared online.
#
# Moreover, privacy concerns are paramount in discussions about the regulation of social media platforms. These platforms collect and process vast amounts of personal data, often without users' explicit consent or understanding. This data is sometimes shared or sold to third parties, raising significant privacy and ethical issues. A government regulatory framework could mandate greater transparency and control for users over their personal information. Additionally, by enforcing strict privacy standards, governments can hold social media companies accountable and protect users from data breaches and misuse. Europe's General Data Protection Regulation (GDPR) serves as a viable model for how effective regulation can contribute to safeguarding user privacy while maintaining digital innovation.
#
# On the other hand, opponents of government regulation argue that such measures may infringe on free speech and stifle innovation. Social media has provided historically marginalized groups with platforms to voice their opinions and advocate for social change. Excessive regulation might curtail these voices and limit the diversity of content shared online. Furthermore, technological innovations that characterize social media ecosystems thrive in non-restricted environments. Regulations perceived to be overly burdensome could stifle creativity and prevent start-ups from entering the market, ultimately diminishing the dynamism of the social media landscape.
#
# However, it is possible to strike a balance between regulation and innovation. Government oversight does not necessarily have to equate to censorship or an undue burden on businesses. Instead, well-considered policies can create an environment where innovation and user protection coexist. By collaborating with technology companies, governments can craft legislation that targets harmful practices while preserving the freedoms that define social media platforms.
#
# In conclusion, while the prospect of government regulation of social media platforms raises concerns about free speech and innovation, its potential benefits—such as curbing the spread of misinformation and enhancing user privacy—are significant. Government oversight, when executed judiciously, can foster a safer and more trustworthy online environment. As social media continues to integrate into every aspect of modern life, finding a balanced approach to regulation is imperative for ensuring that these platforms contribute positively to society.
#
# 🧠 Feedback:
#
# The essay is well‐structured, opening with a clear introduction that situates the debate, followed by body paragraphs on misinformation, privacy, and counterarguments, and concluding with a balanced call for judicious oversight. Your ideas flow logically, but some transitions (for example, between the privacy and opposition sections) feel abrupt and could be smoothed with brief signposting phrases. The arguments are supported with relevant examples like COVID-19 misinformation and the GDPR model, yet you might strengthen them further by citing specific studies or statistics to bolster your claims. The discussion of free speech versus regulation is balanced, though the counterargument paragraph could be deepened by acknowledging potential government overreach or variance in enforcement. Your tone is appropriately formal and measured, but watch for repetitive phrasing—“government regulation” appears multiple times in close succession—and consider varying sentence structures to maintain reader engagement. Grammatically the draft is solid, though you could tighten a few passive constructions (“platforms have become indispensable” could be more direct) and replace generic terms like “harmful effects” with more precise language. Finally, the conclusion effectively summarizes your stance but would benefit from a sharper closing thought or call to action to leave a stronger final impression.
#
# ✍️ Revised:
#
# **Should Social Media Platforms Be Regulated by the Government?**
#
# In the digital era, the way individuals communicate, express ideas, and consume information has been fundamentally transformed by social media platforms. These platforms have become crucial, influencing political discourse, societal norms, and individual well-being. Yet, the debate over whether the government should regulate these platforms is contentious, sparking discussions about freedom of expression, misinformation, and privacy. Although social media offers a space for free expression and connection, there are compelling reasons for government involvement to address issues like misinformation, privacy breaches, and cyberbullying.
#
# A key reason for government regulation lies in combating the pervasive spread of misinformation. Over the past decade, false information has often gone viral with serious real-world consequences. For instance, during political elections, misleading or outright deceptive information can skew public opinion and alter voter behavior. COVID-19 further illustrated the dangers of inaccurate health information, posing risks to public health and safety. Government intervention could mandate stricter fact-checking and content moderation measures on these platforms, thus preserving the integrity of online information. A study from the Massachusetts Institute of Technology found that false news on Twitter spreads six times faster than the truth, highlighting the urgent need for regulatory measures.
#
# Additionally, privacy concerns take center stage in discussions about regulating social media platforms. These platforms collect extensive personal data, often without users' explicit consent or understanding. This data can be shared or sold to third parties, raising significant privacy and ethical concerns. A government regulatory framework could ensure greater transparency and give users more control over their personal information. By enforcing strict privacy standards, governments can hold social media companies accountable and protect users from data breaches and misuse. Europe's General Data Protection Regulation (GDPR) provides a robust model, demonstrating how effective regulation can safeguard user privacy while fostering digital innovation.
#
# In contrast, opponents of government regulation argue that such measures may infringe upon free speech and stifle innovation. Social media has provided platforms for historically marginalized groups to voice their opinions and advocate for social change. Overregulation might curtail these voices and limit the diversity of online content. Moreover, technological innovation flourishes in unrestricted environments. Regulations deemed overly burdensome could stifle creativity and deter start-ups, ultimately diminishing the dynamism of the social media landscape. However, it is essential to acknowledge the risk of government overreach or inconsistency in enforcement, which could amplify these concerns.
#
# Nevertheless, finding a balance between regulation and innovation is possible. Government oversight need not equate to censorship or an undue business burden. Well-crafted policies can create an environment where innovation and user protection coexist harmoniously. By collaborating with technology companies, governments can craft legislation that addresses harmful practices while preserving the freedoms that define social media platforms.
#
# In conclusion, while government regulation of social media platforms raises legitimate concerns about free speech and innovation, its potential benefits—such as curbing misinformation and enhancing user privacy—are substantial. When executed wisely, government oversight can foster a safer, more trustworthy online environment. As social media continues to permeate every aspect of modern life, finding a balanced regulatory approach is crucial for ensuring these platforms positively contribute to society. As citizens and policymakers, we must prioritize this dialogue to navigate the complex intersection of regulation and freedom in the digital age.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">**Should Social Media Platforms Be Regulated by the Government?**
#
# In the digital era, social media platforms represent a transformative force in how individuals communicate, express ideas, and consume information. These platforms have become indispensable, influencing political discourse, societal norms, and even individual well-being. However, the question of whether these platforms should be regulated by the government is a contentious issue, stoking debates about freedom of expression, misinformation, and privacy. While social media provides a space for free expression and connection, government regulation may be necessary to mitigate harmful effects such as the spread of misinformation, violation of privacy, and cyberbullying.
#
# One primary argument for government regulation of social media platforms is the need to combat the rampant spread of misinformation. The past decade has seen numerous instances of false information spreading virally, often with significant real-world consequences. For example, during political elections, misleading or outright false information can influence public opinion and voter behavior. The dissemination of inaccurate health information, particularly evident during the COVID-19 pandemic, poses risks to public health and safety. Government intervention could help ensure that these platforms implement more stringent measures for fact-checking and moderating content, thus preserving the integrity of information shared online.
#
# Moreover, privacy concerns are paramount in discussions about the regulation of social media platforms. These platforms collect and process vast amounts of personal data, often without users' explicit consent or understanding. This data is sometimes shared or sold to third parties, raising significant privacy and ethical issues. A government regulatory framework could mandate greater transparency and control for users over their personal information. Additionally, by enforcing strict privacy standards, governments can hold social media companies accountable and protect users from data breaches and misuse. Europe's General Data Protection Regulation (GDPR) serves as a viable model for how effective regulation can contribute to safeguarding user privacy while maintaining digital innovation.
#
# On the other hand, opponents of government regulation argue that such measures may infringe on free speech and stifle innovation. Social media has provided historically marginalized groups with platforms to voice their opinions and advocate for social change. Excessive regulation might curtail these voices and limit the diversity of content shared online. Furthermore, technological innovations that characterize social media ecosystems thrive in non-restricted environments. Regulations perceived to be overly burdensome could stifle creativity and prevent start-ups from entering the market, ultimately diminishing the dynamism of the social media landscape.
#
# However, it is possible to strike a balance between regulation and innovation. Government oversight does not necessarily have to equate to censorship or an undue burden on businesses. Instead, well-considered policies can create an environment where innovation and user protection coexist. By collaborating with technology companies, governments can craft legislation that targets harmful practices while preserving the freedoms that define social media platforms.
#
# In conclusion, while the prospect of government regulation of social media platforms raises concerns about free speech and innovation, its potential benefits—such as curbing the spread of misinformation and enhancing user privacy—are significant. Government oversight, when executed judiciously, can foster a safer and more trustworthy online environment. As social media continues to integrate into every aspect of modern life, finding a balanced approach to regulation is imperative for ensuring that these platforms contribute positively to society.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">The essay is well‐structured, opening with a clear introduction that situates the debate, followed by body paragraphs on misinformation, privacy, and counterarguments, and concluding with a balanced call for judicious oversight. Your ideas flow logically, but some transitions (for example, between the privacy and opposition sections) feel abrupt and could be smoothed with brief signposting phrases. The arguments are supported with relevant examples like COVID-19 misinformation and the GDPR model, yet you might strengthen them further by citing specific studies or statistics to bolster your claims. The discussion of free speech versus regulation is balanced, though the counterargument paragraph could be deepened by acknowledging potential government overreach or variance in enforcement. Your tone is appropriately formal and measured, but watch for repetitive phrasing—“government regulation” appears multiple times in close succession—and consider varying sentence structures to maintain reader engagement. Grammatically the draft is solid, though you could tighten a few passive constructions (“platforms have become indispensable” could be more direct) and replace generic terms like “harmful effects” with more precise language. Finally, the conclusion effectively summarizes your stance but would benefit from a sharper closing thought or call to action to leave a stronger final impression.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">**Should Social Media Platforms Be Regulated by the Government?**
#
# In the digital era, the way individuals communicate, express ideas, and consume information has been fundamentally transformed by social media platforms. These platforms have become crucial, influencing political discourse, societal norms, and individual well-being. Yet, the debate over whether the government should regulate these platforms is contentious, sparking discussions about freedom of expression, misinformation, and privacy. Although social media offers a space for free expression and connection, there are compelling reasons for government involvement to address issues like misinformation, privacy breaches, and cyberbullying.
#
# A key reason for government regulation lies in combating the pervasive spread of misinformation. Over the past decade, false information has often gone viral with serious real-world consequences. For instance, during political elections, misleading or outright deceptive information can skew public opinion and alter voter behavior. COVID-19 further illustrated the dangers of inaccurate health information, posing risks to public health and safety. Government intervention could mandate stricter fact-checking and content moderation measures on these platforms, thus preserving the integrity of online information. A study from the Massachusetts Institute of Technology found that false news on Twitter spreads six times faster than the truth, highlighting the urgent need for regulatory measures.
#
# Additionally, privacy concerns take center stage in discussions about regulating social media platforms. These platforms collect extensive personal data, often without users' explicit consent or understanding. This data can be shared or sold to third parties, raising significant privacy and ethical concerns. A government regulatory framework could ensure greater transparency and give users more control over their personal information. By enforcing strict privacy standards, governments can hold social media companies accountable and protect users from data breaches and misuse. Europe's General Data Protection Regulation (GDPR) provides a robust model, demonstrating how effective regulation can safeguard user privacy while fostering digital innovation.
#
# In contrast, opponents of government regulation argue that such measures may infringe upon free speech and stifle innovation. Social media has provided platforms for historically marginalized groups to voice their opinions and advocate for social change. Overregulation might curtail these voices and limit the diversity of online content. Moreover, technological innovation flourishes in unrestricted environments. Regulations deemed overly burdensome could stifle creativity and deter start-ups, ultimately diminishing the dynamism of the social media landscape. However, it is essential to acknowledge the risk of government overreach or inconsistency in enforcement, which could amplify these concerns.
#
# Nevertheless, finding a balance between regulation and innovation is possible. Government oversight need not equate to censorship or an undue business burden. Well-crafted policies can create an environment where innovation and user protection coexist harmoniously. By collaborating with technology companies, governments can craft legislation that addresses harmful practices while preserving the freedoms that define social media platforms.
#
# In conclusion, while government regulation of social media platforms raises legitimate concerns about free speech and innovation, its potential benefits—such as curbing misinformation and enhancing user privacy—are substantial. When executed wisely, government oversight can foster a safer, more trustworthy online environment. As social media continues to permeate every aspect of modern life, finding a balanced regulatory approach is crucial for ensuring these platforms positively contribute to society. As citizens and policymakers, we must prioritize this dialogue to navigate the complex intersection of regulation and freedom in the digital age.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
